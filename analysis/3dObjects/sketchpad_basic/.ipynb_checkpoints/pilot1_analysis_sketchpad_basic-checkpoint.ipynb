# %%
import os
import urllib, cStringIO

import pymongo as pm

import matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import seaborn as sns
sns.set_context('poster')
sns.set_style('white')

import numpy as np
from __future__ import division
import scipy.stats as stats
import tabular as tb
import pandas as pd
import json
import re

from PIL import Image
import base64

from helpers import *

# %%
# directory & file hierarchy
exp_path = '3dObjects/sketchpad_basic'
analysis_dir = os.getcwd()
data_dir = os.path.abspath(os.path.join(os.getcwd(),'../../..','data',exp_path))
exp_dir = os.path.abspath(os.path.join(os.getcwd(),'../../..','experiments',exp_path))
sketch_dir = os.path.abspath(os.path.join(os.getcwd(),'../../..','analysis',exp_path,'sketches','pilot1'))

# %%
# set vars 
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'rxdhawkins.me' ## cocolab ip address

# have to fix this to be able to analyze from local
import pymongo as pm
conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['3dObjects']
coll = db['sketchpad_basic']

# %%
S = coll.find({ '$and': [{'iterationName':'pilot1'}, {'eventType': 'stroke'}]}).sort('time')
C = coll.find({ '$and': [{'iterationName':'pilot1'}, {'eventType': 'clickedObj'}]}).sort('time')
print str(S.count()) + ' stroke records in the database.'
print str(C.count()) + ' clickedObj records in the database.'
# Out:
# 44396 stroke records in the database.
# 2804 clickedObj records in the database.

# %%
# print unique gameid's
unique_gameids = coll.find({ '$and': [{'iterationName':'pilot1'}, {'eventType': 'clickedObj'}]}).sort('time').distinct('gameid')
# print map(str,unique_gameids)

# filter out  records that match researcher ID's
jefan = ['A1MMCS8S8CTWKU','A1MMCS8S8CTWKV']
hawkrobe = ['A1BOIDKD33QSDK']
researchers = jefan + hawkrobe
workers = [i for i in coll.find({'iterationName':'pilot1'}).distinct('workerId') if i not in researchers]

# %%
valid_gameids = []
for i,g in enumerate(unique_gameids):
    W = coll.find({ '$and': [{'gameid': g}]}).distinct('workerId')
    for w in W:
        if w in workers:
            X = coll.find({ '$and': [{'workerId': w}, {'gameid': g}]}).distinct('trialNum') ## # of trials completed
            eventType = coll.find({ '$and': [{'workerId': w}]}).distinct('eventType')
            print i, w[:4], len(X), str(eventType[0])
            if (str(eventType[0])=='clickedObj') & (len(X)==32):
                valid_gameids.append(g)
print '   ===========   '

## filter if the pair cheated by writing words or using other symbols
cheaty = ['8155-e46a25a3-9259-4b76-80e9-5bd79b6bdd97','6224-ab96ed5c-2a98-477c-aae2-7398b9e5b237']
valid_gameids = [i for i in valid_gameids if i not in cheaty]

print str(len(valid_gameids)) + ' valid gameIDs (# complete games).'

df = pd.DataFrame([valid_gameids])
df = df.transpose()
df.columns=['valid_gameids']
df.to_csv('valid_gameids_pilot1.csv')
# Out:
# 0  2 stroke
# 1 AA4K 32 stroke
# 1 A31K 32 clickedObj
# 2 A2CY 32 stroke
# 2 AM8O 32 clickedObj
# 3 A1M7 32 stroke
# 3 A3M7 32 clickedObj
# 4 A3IB 32 stroke
# 4 AVD6 32 clickedObj
# 5 A335 32 stroke
# 5 AM8H 32 clickedObj
# 6 A13B 32 stroke
# 6 A3N8 32 clickedObj
# 7 AFR4 32 stroke
# 7 A2MK 32 clickedObj
# 8 A25D 32 stroke
# 8 AOKT 32 clickedObj
# 9 AK7N 32 stroke
# 9 A21H 32 clickedObj
# 10 A802 32 stroke
# 10 A4IH 32 clickedObj
# 11 AA4K 32 stroke
# 11 A2ZF 32 clickedObj
# 12 A3BX 32 stroke
# 12 A3H3 32 clickedObj
# 13 A25N 32 stroke
# 13 A39G 31 clickedObj
# 14 ANT9 6 stroke
# 14 A27G 5 clickedObj
# 15 A36M 32 stroke
# 15 A13T 32 clickedObj
# 16 A55C 32 stroke
# 16 A2LU 32 clickedObj
# 17 A2UN 32 stroke
# 17 A2JO 32 clickedObj
# 18 A2GB 32 stroke
# 18 A3QE 32 clickedObj
# 19 A1B5 32 stroke
# 19 A3Q0 32 clickedObj
# 20 A3EU 32 stroke
# 20 A1XT 32 clickedObj
# 21 A3IF 32 stroke
# 21 A2Y2 32 clickedObj
# 22 AY7W 32 stroke
# 22 AGA1 32 clickedObj
# 23 A3NJ 1 stroke
# 23 AUAN 1 clickedObj
# 24 A24D 6 stroke
# 24 A3PC 5 clickedObj
# 25 A3VR 32 stroke
# 25 A2GG 32 clickedObj
# 26 A2WW 32 stroke
# 26 A1WX 32 clickedObj
# 27 A4ZW 32 stroke
# 27 AS1Q 32 clickedObj
# 28 A16S 32 stroke
# 28 A2M9 32 clickedObj
# 29 A11Y 32 stroke
# 29 A194 32 clickedObj
# 30 ATF7 32 stroke
# 30 A2YO 32 clickedObj
# 31 ADDI 32 stroke
# 31 A2WS 32 clickedObj
# 32 AOIR 32 stroke
# 32 A2E3 32 clickedObj
# 33 AEPH 32 stroke
# 33 A9WI 32 clickedObj
# 34 A3OC 32 stroke
# 34 A1F3 32 clickedObj
# 35 A2ZD 32 stroke
# 35 A2XJ 32 clickedObj
# 36 A3QU 32 stroke
# 36 A2UO 32 clickedObj
# 37 A2XN 32 stroke
# 37 A3OM 32 clickedObj
# 38 A2OF 32 stroke
# 38 A2CO 32 clickedObj
# 39 A15X 4 stroke
# 39 A3IG 3 clickedObj
# 40 A2P4 13 stroke
# 40 A2P7 13 clickedObj
# 41 A38N 32 stroke
# 41 A390 32 clickedObj
# 42 A213 32 stroke
# 42 A1OD 32 clickedObj
# 43 A183 4 stroke
# 43 A3LF 3 clickedObj
# 44 A1EY 32 stroke
# 44 A36Z 32 clickedObj
# 45 AD8J 32 stroke
# 45 AO7F 32 clickedObj
# 46 AEO8 32 stroke
# 46 A31A 32 clickedObj
# 47 A1SL 32 stroke
# 47 A127 32 clickedObj
# 48 APR6 32 stroke
# 48 AROO 32 clickedObj
# 49 A3AF 2 stroke
# 49 A2ZR 1 clickedObj
# 50 A10X 32 stroke
# 50 A3NM 32 clickedObj
# 51 A1OH 32 stroke
# 51 A3HC 32 clickedObj
# 52 ANYB 2 stroke
# 52 A34P 1 clickedObj
# 53 A2IR 11 stroke
# 53 A4IE 10 clickedObj
# 54 A16G 32 stroke
# 54 A214 32 clickedObj
# 55 A1XD 32 stroke
# 55 ADKK 32 clickedObj
# 56 AN09 32 stroke
# 56 A4FG 32 clickedObj
# 57 A1JL 11 stroke
# 57 AT5N 10 clickedObj
# 58 A3CA 21 stroke
# 58 A3HH 21 clickedObj
# 59 A224 32 stroke
# 59 A1LB 32 clickedObj
# 60 A289 32 stroke
# 60 A3LR 32 clickedObj
# 61 A2T6 32 stroke
# 61 A3KK 32 clickedObj
# 62 A36P 32 stroke
# 62 A18S 32 clickedObj
# 63 ANUG 32 stroke
# 63 A3PI 32 clickedObj
# 64 AEXF 32 stroke
# 64 AJR9 32 clickedObj
# 65 A2A0 32 stroke
# 65 AEO4 32 clickedObj
# 66 A36Y 32 stroke
# 66 A1AY 32 clickedObj
# 67 A1DI 32 stroke
# 67 A2MF 32 clickedObj
# 68 A2TF 32 stroke
# 68 A25Z 32 clickedObj
# 69 A2UU 32 stroke
# 69 A258 32 clickedObj
# 70 A1X5 32 stroke
# 70 A3UU 32 clickedObj
# 71 AKX5 32 stroke
# 71 A3IL 32 clickedObj
# 72 A2RO 32 stroke
# 72 A1QG 32 clickedObj
# 73 A1YP 32 stroke
# 73 A1CC 32 clickedObj
# 74 A1B9 32 stroke
# 74 A13P 32 clickedObj
# 75 A2Q1 32 stroke
# 75 A3PQ 32 clickedObj
# 76 A3MB 32 stroke
# 76 A17K 32 clickedObj
# 77 A22Z 32 stroke
# 77 A3NH 32 clickedObj
# 78 AMDX 32 stroke
# 78 A293 32 clickedObj
# 79 A6OR 10 stroke
# 79 A1A6 9 clickedObj
# 80 A3R4 32 stroke
# 80 A132 32 clickedObj
# 81 A2DV 32 stroke
# 81 A3JA 32 clickedObj
# 82 A2VL 32 stroke
# 82 A3MF 32 clickedObj
# 83 A3PD 16 stroke
# 83 A190 16 clickedObj
# 84 A17P 32 stroke
# 84 A2LC 32 clickedObj
# 85 A3D3 32 stroke
# 85 A9V0 32 clickedObj
# 86 A1BO 32 stroke
# 86 A1SO 32 clickedObj
# 87 A1MA 32 stroke
# 87 A2C4 32 clickedObj
# 88 A1ZT 32 stroke
# 88 AV21 32 clickedObj
# 89 A1CJ 17 stroke
# 89 AGXZ 17 clickedObj
# 90 A3BD 32 stroke
# 90 A13F 32 clickedObj
# 91 A3GE 32 stroke
# 91 A3S1 32 clickedObj
# 92 ABLO 32 stroke
# 92 AFSB 32 clickedObj
# 93 A2DW 32 stroke
# 93 A12H 32 clickedObj
# 94 A281 32 stroke
# 94 A30M 32 clickedObj
# 95 A77K 32 stroke
# 95 ACJT 32 clickedObj
# 96 AT46 32 stroke
# 96 A1EF 32 clickedObj
# 97 A2SH 32 stroke
# 97 A7N3 32 clickedObj
# 98 A3CT 32 stroke
# 98 ADIA 32 clickedObj
#    ===========
# 81 valid gameIDs (# complete games).

# %%
TrialNum = []
GameID = []
Condition = []
Target = []
Distractor1 = []
Distractor2 = []
Distractor3 = []
Outcome = []
Response = []
numStrokes = []
drawDuration = [] # in seconds
svgStringLength = [] # sum of svg string for whole sketch
svgStringLengthPerStroke = [] # svg string length per stroke
numCurvesPerSketch = [] # number of curve segments per sketch
numCurvesPerStroke = [] # mean number of curve segments per stroke
svgStringStd = [] # std of svg string length across strokes for this sketch
Outcome = []
Pose = []

for g in valid_gameids:
    print 'Analyzing game: ', g

    X = coll.find({ '$and': [{'gameid': g}, {'eventType': 'clickedObj'}]}).sort('time')
    Y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}]}).sort('time')

    for t in X:
        targetname = t['intendedName']
        distractors = [t['object2Name'],t['object3Name'],t['object4Name']]
        full_list = [t['intendedName'],t['object2Name'],t['object3Name'],t['object4Name']] 
        y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}, {'trialNum': t['trialNum']}]}).sort('time')
        ns = y.count()
        numStrokes.append(ns)
        drawDuration.append((y.__getitem__(ns-1)['time'] - y.__getitem__(0)['time'])/1000) # in seconds
        ls = [len(_y['svgData']) for _y in y]
        svgStringLength.append(reduce(lambda x, y: x + y, ls))
        y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}, {'trialNum': t['trialNum']}]}).sort('time')
        num_curves = [len([m.start() for m in re.finditer('c', _y['svgData'])]) for _y in y]
        numCurvesPerSketch.append(reduce(lambda x, y: x + y, num_curves))
        numCurvesPerStroke.append(reduce(lambda x, y: x + y, num_curves)/ns)
        svgStringLengthPerStroke.append(reduce(lambda x, y: x + y, ls)/ns)
        svgStringStd.append(np.std(ls))
    #     ## aggregate game metadata
        TrialNum.append(t['trialNum'])
        GameID.append(t['gameid'])        
        Target.append(targetname)
        Condition.append(t['condition'])
        Response.append(t['clickedName'])
        Outcome.append(t['correct'])
        Distractor1.append(distractors[0])
        Distractor2.append(distractors[1])
        Distractor3.append(distractors[2])
        Pose.append(t['pose'])
# Out:
# Analyzing game:  0535-a2298fee-9fee-480a-b610-97868839a2f3
# Analyzing game:  8155-e46a25a3-9259-4b76-80e9-5bd79b6bdd97
# Analyzing game:  6450-e912a14e-23df-4035-ac9a-b2cf74f15b98
# Analyzing game:  7593-f0489503-8b0b-485a-ae39-e259368664ec
# Analyzing game:  2204-3d282337-deb9-4e23-94b2-6cd048a8a033
# Analyzing game:  2848-1779ba4d-c84b-4050-8a1f-e4b733ceb6a7
# Analyzing game:  1445-76cc5a87-402d-4f8b-b58a-9e97a0613616
# Analyzing game:  5874-f8051e0a-38ec-4cd4-97bd-e9293354ea19
# Analyzing game:  8819-83e41234-d6c0-4b51-88e5-0f0dec886711
# Analyzing game:  8303-b6a53fd7-758c-40fe-a2fc-c2ee44cd976e
# Analyzing game:  9272-e3357074-a213-422e-9f2e-cd651eab81ab
# Analyzing game:  8975-103e8e1a-5b9a-4a89-928c-4954f989b06b
# Analyzing game:  3644-5c59877e-a907-4a31-b23b-5f4c9a0ef09a
# Analyzing game:  3515-7815239c-7927-4d44-b3bf-11524bcc9bf6
# Analyzing game:  8037-403f337e-748b-496c-a88f-db09ec862568
# Analyzing game:  4677-e7bbc55f-fbf4-45d4-bf02-598e831e3427
# Analyzing game:  7191-d5fd9020-902a-4f79-9843-a256c5dacb37
# Analyzing game:  7948-e1fb7fa9-ffc4-468c-9c9f-fe8e1d4e3bc2
# Analyzing game:  9327-c0beefca-0873-4b8a-9150-51c2a0fb82fc
# Analyzing game:  1075-1cd285ee-23cc-431e-a957-40e72b57cd95
# Analyzing game:  3687-f9f943c4-dd2d-4cc0-a28c-6033f019cfad
# Analyzing game:  6119-217c3807-f595-4732-a2cc-66ae9b0f2a5f
# Analyzing game:  3207-fde2baa0-61b8-45aa-b255-ebec98351506
# Analyzing game:  0273-d557931d-9a9e-49e2-ac92-9da282521a06
# Analyzing game:  4546-f9fcfb8d-a3be-42f3-9c65-3feda50858ff
# Analyzing game:  0907-f76165c1-464e-426b-960d-02a18e0f468a
# Analyzing game:  8727-a1a01879-fc3b-4837-b1fe-5729facc72df
# Analyzing game:  7596-77f299a5-42bd-4985-83c2-eb7bf7d7bda9
# Analyzing game:  7803-4b0bd7fd-829d-4de9-aa70-9be1cef8062f
# Analyzing game:  7266-68826e7a-2875-4750-9ddc-4b5397aaf9a5
# Analyzing game:  7848-f3fe2b6f-713b-4695-9fbd-ba4fa6897887
# Analyzing game:  7522-6780f02a-dcc5-4663-99f0-9fb30ab8b1c8
# Analyzing game:  2552-aa93cff3-83d0-4a21-91b6-0770489f09fc
# Analyzing game:  4604-7927e887-3e5c-40b8-935c-536321ddf5d8
# Analyzing game:  6773-64175755-f825-4336-85ad-9e0bfd230b69
# Analyzing game:  4023-028179e7-5141-423e-aed3-750ebe1b7f0b
# Analyzing game:  6106-603e561a-34d6-4660-ae8c-742d537c3c8d
# Analyzing game:  4997-0bd6d143-637c-4248-b8e4-de5ece20c185
# Analyzing game:  6224-ab96ed5c-2a98-477c-aae2-7398b9e5b237
# Analyzing game:  6575-7d152f85-a68c-4282-872b-aa28797839b8
# Analyzing game:  4178-df447b76-1be6-49c6-a42f-bd882d442998
# Analyzing game:  5157-5c5cccb1-04ca-45cf-9c6d-3a9fe57c5ce2
# Analyzing game:  5742-f8753fba-b31c-44f3-a3ad-76fa38df4345
# Analyzing game:  7963-5ebb8094-114b-4727-93b4-c4719cacc33e
# Analyzing game:  3968-35e2fcdb-c9e3-4556-9f7b-d47d38cbf130
# Analyzing game:  4143-3aed2f05-e0e6-4117-9d93-1849a3a7e567
# Analyzing game:  1960-02b34a68-8229-460a-9ee4-3b8a411cd76d
# Analyzing game:  8651-485e82ff-2062-4121-9936-5089b41d6e95
# Analyzing game:  0793-9115d164-4bed-4928-8031-630161232275
# Analyzing game:  5360-6c999d75-4224-445c-b5c8-0b952d5c3afc
# Analyzing game:  4905-7e1e70bf-3137-46b8-b321-f24646df3a02
# Analyzing game:  8181-c44c672e-1f04-4d39-b984-dff5f557e8c9
# Analyzing game:  3432-70b6af63-3c20-4dba-94fe-9f40a60b440d
# Analyzing game:  1506-39dc44f7-ee0a-4610-bd1b-6b251cdc7286
# Analyzing game:  9364-fa0394b1-f27b-4484-b04f-5f702f5295bf
# Analyzing game:  8791-2219258a-dbbc-45ea-a65b-e0d4ab6f70ba
# Analyzing game:  7601-00e2c292-0dd9-47d0-80c1-dedce5688994
# Analyzing game:  9857-d7c518af-8951-43d2-b82c-b70083319e91
# Analyzing game:  5613-9813bf94-70a7-4b1f-a211-ea5692bd70f3
# Analyzing game:  6420-1b4bd32f-d5de-4d4b-83f9-f5c2b5378c46
# Analyzing game:  6186-2f90eb49-9b9a-4809-9be6-29a90e024d4f
# Analyzing game:  5396-864b6ad5-36a9-4e6f-ac73-2e7b848c394b
# Analyzing game:  9460-e4d8a2fd-7a5a-4d25-ae41-127894d151ba
# Analyzing game:  5062-3a0f07c2-94d8-46da-b07b-eec2b4a61ff4
# Analyzing game:  7180-6ff89bfe-8682-412d-af98-c7deb0ad5a21
# Analyzing game:  6247-a34e373a-217c-4a0a-a8fc-9becfef19917
# Analyzing game:  7153-7156a665-f7f2-4d4c-a564-6860f102553c
# Analyzing game:  8791-b1dcfcc0-9352-4400-8369-4d08ec32315f
# Analyzing game:  1819-c3a24d90-67d5-4809-86e7-fd593aa8a5d4
# Analyzing game:  5034-7b58800e-9ac1-4d02-92a8-2b254989f56a
# Analyzing game:  7739-793fdb53-3984-416e-a150-18402825b54f
# Analyzing game:  5907-3a9cd530-1185-49fb-b80c-a01b8135ab19
# Analyzing game:  2464-c53624ef-35fd-4408-9c94-3cdd233debe7
# Analyzing game:  7442-b6cc7ffe-65f4-4bd0-a58b-ee9f094dd790
# Analyzing game:  0007-978f80e4-e27a-45b4-8084-7c0e90628426
# Analyzing game:  1350-d657e06f-e679-4eb8-b73d-f2709da1f958
# Analyzing game:  8242-be9b13ac-dcbb-409d-8273-385474deebcf
# Analyzing game:  4754-285207b9-aa4d-4004-9c25-9b037e0cc76e
# Analyzing game:  6610-9b5cd7f2-433c-42a9-a00b-7eb764377141
# Analyzing game:  6675-0a3a8570-aeb6-4859-af81-a0a49490e336
# Analyzing game:  5613-63f88b6b-4ce7-427e-8bf7-08d14ece0224
# Analyzing game:  8920-5c5e45df-c4a7-4c73-b8b5-8bc5a7d639a0
# Analyzing game:  1154-111c8889-c505-4bc8-ac56-ac5a2e8b225b

# %%
iteration = ['pilot1']*len(GameID)

_D = pd.DataFrame([GameID,TrialNum,Condition, Target, drawDuration, Outcome, Response, numStrokes, \
                  svgStringLength, svgStringLengthPerStroke, svgStringStd, Distractor1, Distractor2, \
                   Distractor3, Pose, iteration]) \

D =_D.transpose()
D.columns = ['gameID','trialNum','condition', 'target', 'drawDuration','outcome', 'response', \
             'numStrokes', 'svgStringLength', 'svgStringLengthPerStroke', 'svgStringStd', \
            'Distractor1', 'Distractor2', 'Distractor3', 'pose', 'iteration']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-9d20776e7df6> in <module>()
# ----> 1 iteration = ['pilot1']*len(GameID)
#       2
#       3 _D = pd.DataFrame([GameID,TrialNum,Condition, Target, drawDuration, Outcome, Response, numStrokes,                   svgStringLength, svgStringLengthPerStroke, svgStringStd, Distractor1, Distractor2,                    Distractor3, Pose, iteration])
#       4 D =_D.transpose()
#       5 D.columns = ['gameID','trialNum','condition', 'target', 'drawDuration','outcome', 'response',              'numStrokes', 'svgStringLength', 'svgStringLengthPerStroke', 'svgStringStd',             'Distractor1', 'Distractor2', 'Distractor3', 'pose', 'iteration']
#
# NameError: name 'GameID' is not defined

# %%
## add png to D dataframe
png = []
for g in valid_gameids:
    X = coll.find({ '$and': [{'gameid': g}, {'eventType': 'clickedObj'}]}).sort('time')
    Y = coll.find({ '$and': [{'gameid': g}, {'eventType': 'stroke'}]}).sort('time')
    # print out sketches from all trials from this game
    for t in X: 
        png.append(t['pngString'])
D = D.assign(png=pd.Series(png).values)

iteration = ['pilot1']*len(D['gameID'].values)
D = D.assign(iteration=pd.Series(iteration).values)

# %%
# save D out as group_data.csv 
D.to_csv(os.path.join(analysis_dir,'sketchpad_basic_pilot1_group_data.csv'))

# %%
# get summary statistics
all_games = np.unique(D['gameID'])
further_strokes = []
closer_strokes = []
further_svgLength = []
closer_svgLength = []
further_svgStd = []
closer_svgStd = []
further_svgLengthPS = []
closer_svgLengthPS = []
further_drawDuration = []
closer_drawDuration = []
further_accuracy = []
closer_accuracy = []
for game in all_games:    
    further_strokes.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['numStrokes'].mean())
    closer_strokes.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['numStrokes'].mean())
    further_svgLength.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['svgStringLength'].mean())
    closer_svgLength.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['svgStringLength'].mean())
    further_svgStd.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['svgStringStd'].mean())
    closer_svgStd.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['svgStringStd'].mean())    
    further_svgLengthPS.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['svgStringLengthPerStroke'].mean())
    closer_svgLengthPS.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['svgStringLengthPerStroke'].mean())
    further_drawDuration.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['drawDuration'].mean())
    closer_drawDuration.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['drawDuration'].mean())
    further_accuracy.append(D[(D['gameID']== game) & (D['condition'] == 'further')]['outcome'].mean())
    closer_accuracy.append(D[(D['gameID']== game) & (D['condition'] == 'closer')]['outcome'].mean())
    
further_strokes, closer_strokes, further_svgLength, closer_svgLength, \
further_svgStd, closer_svgStd, further_svgLengthPS, closer_svgLengthPS, \
further_drawDuration, closer_drawDuration, further_accuracy, closer_accuracy = map(np.array, \
[further_strokes, closer_strokes, further_svgLength, closer_svgLength,\
 further_svgStd, closer_svgStd, further_svgLengthPS, closer_svgLengthPS, \
further_drawDuration, closer_drawDuration, further_accuracy, closer_accuracy])

# %%
print further_strokes.mean(), closer_strokes.mean()
print further_svgLength.mean(), closer_svgLength.mean()
print further_svgStd.mean(), closer_svgStd.mean()
print further_svgLengthPS.mean(), closer_svgLengthPS.mean()
print further_drawDuration.mean(), closer_drawDuration.mean()
print further_accuracy.mean(), closer_accuracy.mean()
# Out:
# 12.5052710843 19.7740963855
# 1193.51355422 1914.06626506
# 128.33230837 176.846728013
# 209.729571105 201.265486145
# 14.2534337349 28.9185835843
# 0.99171686747 0.863704819277

# %%
fig = plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
lb = 0
ub = 24
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_strokes,further_strokes,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('number of strokes')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(2,2,2)
lb = 0
ub = 3000
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_svgLength,further_svgLength,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.tight_layout()
plt.title('svg string length')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(2,2,3)
lb = 0
ub = 300
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_svgStd,further_svgStd,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('stroke variability')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(2,2,4)
lb = 0
ub = 300
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_svgLengthPS,further_svgLengthPS,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.tight_layout()
plt.title('svg length per stroke')
plt.xlabel('closer')
plt.ylabel('further')
save_out = 1
if not os.path.exists('plots'):
    os.makedirs('plots')
if save_out:
    save('plots/svg_summary_scatter', ext='pdf', close=False, verbose=True)
# Out:
# Saving figure to 'plots/svg_summary_scatter.pdf'... Done

# %%
fig = plt.figure(figsize=(8,4))
lb = 0
ub = 1.03
plt.subplot(1,2,1)
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_accuracy,further_accuracy,64,(0.8,0.4,0.4))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('accuracy')
plt.xlabel('closer')
plt.ylabel('further')
plt.subplot(1,2,2)
lb = 0
ub = 36
plt.plot([lb,ub],[lb,ub],'k--')
plt.scatter(closer_drawDuration,further_drawDuration,64,(0.75,0.3,0.2))
plt.xlim([lb,ub])
plt.ylim([lb,ub])
plt.title('draw duration')
plt.xlabel('closer')
plt.ylabel('further')
plt.tight_layout()
save_out = 1
if save_out:
    helpers.save('plots/performance_summary_scatter', ext='pdf', close=False, verbose=True)

# %%
def get_canonical(category):    
    stimFile = os.path.join(exp_dir,'stimList_subord.js')
    with open(stimFile) as f:
        stimList = json.load(f)    
    allviews = [i['filename'] for i in stimList if i['basic']==category]
    canonical = [a for a in allviews if a[-8:]=='0035.png']    
    return canonical

def get_actual_pose(subordinate,pose):
    stimFile = os.path.join(exp_dir,'stimList_subord.js')
    with open(stimFile) as f:
        stimList = json.load(f)
    inpose = [i['filename'] for i in stimList if (i['subordinate']==subordinate) and (i['pose']==pose)]
    return inpose
    
def get_subord_names(category):
    full_names = get_canonical(category)    
    return [c.split('_')[2] for c in full_names]

def get_basic_names(subordinate):
    stimFile = os.path.join(exp_dir,'stimList_subord.js')
    with open(stimFile) as f:
        stimList = json.load(f)   
    allviews = [i['filename'] for i in stimList if i['subordinate']==subordinate]
    canonical = [a for a in allviews if a[-8:]=='0035.png']      
    return canonical[0].split('_')[0]

def build_url_from_category(category):
    full_names = get_canonical(category)
    url_prefix = 'https://s3.amazonaws.com/sketchloop-images-subord/'
    urls = []
    for f in full_names:
        urls.append(url_prefix + f)
    return urls

def build_url_from_filenames(filenames):
    url_prefix = 'https://s3.amazonaws.com/sketchloop-images-subord/'
    urls = []
    for f in filenames:
        urls.append(url_prefix + f)
    return urls

def plot_from_url(URL):
    file = cStringIO.StringIO(urllib.urlopen(URL).read())
    img = Image.open(file)    

def plot_gallery(category):
    import matplotlib.pyplot as plt
    import matplotlib.gridspec as gridspec

    plt.figure(figsize = (8,8))
    gs1 = gridspec.GridSpec(8, 8)
    gs1.update(wspace=0.025, hspace=0.05)

    url_prefix = 'https://s3.amazonaws.com/sketchloop-images-subord/'
    for (i,c) in enumerate(category):
        URL = url_prefix + c
        file = cStringIO.StringIO(urllib.urlopen(URL).read())
        img = Image.open(file)
        p = plt.subplot(3,3,i+1)
        plt.imshow(img)
        p.get_xaxis().set_ticklabels([])
        p.get_yaxis().set_ticklabels([])
        p.get_xaxis().set_ticks([])
        p.get_yaxis().set_ticks([])
        p.set_aspect('equal')
        subord = c.split('_')[2]
        plt.title(subord)
    plt.tight_layout()

# %%
## print out sketches with target & distractors from this game
import traceback
backup_path_images = '/Users/judithfan/Dropbox/stimuli_repository/subordinate_allrotations_6_minified'

_valid_gameids = valid_gameids[:3]

run_this = 0
if run_this:
#     all_games = click_files
    for g in valid_gameids:
        print 'Printing out sketches from game: ' + g
        _D = D[(D.gameID==g)]
        _D = _D.sort_values(by=['target'])
        _i = 1
        textsize=12
        fig = plt.figure(figsize=(16,6))        
        for i,_d in _D.iterrows():
            imgData = _d['png']
            filestr = base64.b64decode(imgData)
            target_sketch_dir = os.path.join(analysis_dir,'sketches','sketch')
            if not os.path.exists(target_sketch_dir):
                os.makedirs(target_sketch_dir)
            fname = os.path.join(target_sketch_dir,'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '.png')
            with open(fname, "wb") as fh:
                fh.write(imgData.decode('base64'))
            textsize = 16
            # first plot the target
            im = Image.open(fname)
            p = plt.subplot(2,4,1)
            plt.imshow(im)
            sns.set_style('white')
            k = p.get_xaxis().set_ticklabels([])
            k = p.get_yaxis().set_ticklabels([])
            k = p.get_xaxis().set_ticks([])
            k = p.get_yaxis().set_ticks([])        
            targetname = _d['target']
            distractors = [_d['Distractor1'],_d['Distractor2'],_d['Distractor3']]
            full_list = [_d['target'],_d['Distractor1'],_d['Distractor2'],_d['Distractor3']] 
            outcome = _d['outcome']
            response = _d['response']        
            if outcome == 1:
                sides = ['bottom','top','right','left']
                for s in sides:
                    p.spines[s].set_color((0.4,0.8,0.4))
                    p.spines[s].set_linewidth(4)                               
            else:
                sides = ['bottom','top','right','left']
                for s in sides:
                    p.spines[s].set_color((0.9,0.2,0.2))
                    p.spines[s].set_linewidth(4)                      
            plt.title(targetname,fontsize=textsize)
            plt.ylabel('v:' + response,fontsize=textsize-2)        
        
            # fig = plt.figure(figsize=(8,3))
            for (i,d) in enumerate(full_list):
                if os.path.exists(backup_path_images):
                    if hasattr(t, 'pose'):
                        fn = os.path.join(backup_path_images,get_actual_pose(d,pose)[0])
                    else:
                        fn = os.path.join(backup_path_images,get_actual_pose(d,35)[0])
                else:
                    if hasattr(t, 'pose'):
                        pose = t['pose']
                        URL = build_url_from_filenames(get_actual_pose(d,pose)[0])
                    else:
                        URL = full_dict[d]
                    fn = cStringIO.StringIO(urllib.urlopen(URL).read())
                img = Image.open(fn)
                p = plt.subplot(2,4,i+5)
                plt.imshow(img)
                p.get_xaxis().set_ticklabels([])
                p.get_yaxis().set_ticklabels([])
                p.get_xaxis().set_ticks([])
                p.get_yaxis().set_ticks([])
                p.set_aspect('equal')   
                plt.title(d)

            sketch_dir = os.path.join(analysis_dir,'sketches','full_display')
            if not os.path.exists(sketch_dir):
                os.makedirs(os.path.join(analysis_dir,'sketches','full_display'))
            filepath = os.path.join(sketch_dir,'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']))
            save(filepath, ext='png', close=True, verbose=False)
# Out:
# Printing out sketches from game: 0535-a2298fee-9fee-480a-b610-97868839a2f3
# Printing out sketches from game: 8155-e46a25a3-9259-4b76-80e9-5bd79b6bdd97
# Printing out sketches from game: 6450-e912a14e-23df-4035-ac9a-b2cf74f15b98
# Printing out sketches from game: 7593-f0489503-8b0b-485a-ae39-e259368664ec
# Printing out sketches from game: 2204-3d282337-deb9-4e23-94b2-6cd048a8a033
# Printing out sketches from game: 2848-1779ba4d-c84b-4050-8a1f-e4b733ceb6a7
# Printing out sketches from game: 1445-76cc5a87-402d-4f8b-b58a-9e97a0613616
# Printing out sketches from game: 5874-f8051e0a-38ec-4cd4-97bd-e9293354ea19
# Printing out sketches from game: 8819-83e41234-d6c0-4b51-88e5-0f0dec886711
# Printing out sketches from game: 8303-b6a53fd7-758c-40fe-a2fc-c2ee44cd976e
# Printing out sketches from game: 9272-e3357074-a213-422e-9f2e-cd651eab81ab
# Printing out sketches from game: 8975-103e8e1a-5b9a-4a89-928c-4954f989b06b
# Printing out sketches from game: 3644-5c59877e-a907-4a31-b23b-5f4c9a0ef09a
# Printing out sketches from game: 3515-7815239c-7927-4d44-b3bf-11524bcc9bf6
# Printing out sketches from game: 8037-403f337e-748b-496c-a88f-db09ec862568
# Printing out sketches from game: 4677-e7bbc55f-fbf4-45d4-bf02-598e831e3427
# Printing out sketches from game: 7191-d5fd9020-902a-4f79-9843-a256c5dacb37
# Printing out sketches from game: 7948-e1fb7fa9-ffc4-468c-9c9f-fe8e1d4e3bc2
# Printing out sketches from game: 9327-c0beefca-0873-4b8a-9150-51c2a0fb82fc
# Printing out sketches from game: 1075-1cd285ee-23cc-431e-a957-40e72b57cd95
# Printing out sketches from game: 3687-f9f943c4-dd2d-4cc0-a28c-6033f019cfad
# Printing out sketches from game: 6119-217c3807-f595-4732-a2cc-66ae9b0f2a5f
# Printing out sketches from game: 3207-fde2baa0-61b8-45aa-b255-ebec98351506
# Printing out sketches from game: 0273-d557931d-9a9e-49e2-ac92-9da282521a06
# Printing out sketches from game: 4546-f9fcfb8d-a3be-42f3-9c65-3feda50858ff
# Printing out sketches from game: 0907-f76165c1-464e-426b-960d-02a18e0f468a
# Printing out sketches from game: 8727-a1a01879-fc3b-4837-b1fe-5729facc72df
# Printing out sketches from game: 7596-77f299a5-42bd-4985-83c2-eb7bf7d7bda9
# Printing out sketches from game: 7803-4b0bd7fd-829d-4de9-aa70-9be1cef8062f
# Printing out sketches from game: 7266-68826e7a-2875-4750-9ddc-4b5397aaf9a5
# Printing out sketches from game: 7848-f3fe2b6f-713b-4695-9fbd-ba4fa6897887
# Printing out sketches from game: 7522-6780f02a-dcc5-4663-99f0-9fb30ab8b1c8
# Printing out sketches from game: 2552-aa93cff3-83d0-4a21-91b6-0770489f09fc
# Printing out sketches from game: 4604-7927e887-3e5c-40b8-935c-536321ddf5d8
# Printing out sketches from game: 6773-64175755-f825-4336-85ad-9e0bfd230b69
# Printing out sketches from game: 4023-028179e7-5141-423e-aed3-750ebe1b7f0b
# Printing out sketches from game: 6106-603e561a-34d6-4660-ae8c-742d537c3c8d
# Printing out sketches from game: 4997-0bd6d143-637c-4248-b8e4-de5ece20c185
# Printing out sketches from game: 6224-ab96ed5c-2a98-477c-aae2-7398b9e5b237
# Printing out sketches from game: 6575-7d152f85-a68c-4282-872b-aa28797839b8
# Printing out sketches from game: 4178-df447b76-1be6-49c6-a42f-bd882d442998
# Printing out sketches from game: 5157-5c5cccb1-04ca-45cf-9c6d-3a9fe57c5ce2
# Printing out sketches from game: 5742-f8753fba-b31c-44f3-a3ad-76fa38df4345
# Printing out sketches from game: 7963-5ebb8094-114b-4727-93b4-c4719cacc33e
# Printing out sketches from game: 3968-35e2fcdb-c9e3-4556-9f7b-d47d38cbf130
# Printing out sketches from game: 4143-3aed2f05-e0e6-4117-9d93-1849a3a7e567
# Printing out sketches from game: 1960-02b34a68-8229-460a-9ee4-3b8a411cd76d
# Printing out sketches from game: 8651-485e82ff-2062-4121-9936-5089b41d6e95
# Printing out sketches from game: 0793-9115d164-4bed-4928-8031-630161232275
# Printing out sketches from game: 5360-6c999d75-4224-445c-b5c8-0b952d5c3afc
# Printing out sketches from game: 4905-7e1e70bf-3137-46b8-b321-f24646df3a02
# Printing out sketches from game: 8181-c44c672e-1f04-4d39-b984-dff5f557e8c9
# Printing out sketches from game: 3432-70b6af63-3c20-4dba-94fe-9f40a60b440d
# Printing out sketches from game: 1506-39dc44f7-ee0a-4610-bd1b-6b251cdc7286
# Printing out sketches from game: 9364-fa0394b1-f27b-4484-b04f-5f702f5295bf
# Printing out sketches from game: 8791-2219258a-dbbc-45ea-a65b-e0d4ab6f70ba
# Printing out sketches from game: 7601-00e2c292-0dd9-47d0-80c1-dedce5688994
# Printing out sketches from game: 9857-d7c518af-8951-43d2-b82c-b70083319e91
# Printing out sketches from game: 5613-9813bf94-70a7-4b1f-a211-ea5692bd70f3
# Printing out sketches from game: 6420-1b4bd32f-d5de-4d4b-83f9-f5c2b5378c46
# Printing out sketches from game: 6186-2f90eb49-9b9a-4809-9be6-29a90e024d4f
# Printing out sketches from game: 5396-864b6ad5-36a9-4e6f-ac73-2e7b848c394b
# Printing out sketches from game: 9460-e4d8a2fd-7a5a-4d25-ae41-127894d151ba
# Printing out sketches from game: 5062-3a0f07c2-94d8-46da-b07b-eec2b4a61ff4
# Printing out sketches from game: 7180-6ff89bfe-8682-412d-af98-c7deb0ad5a21
# Printing out sketches from game: 6247-a34e373a-217c-4a0a-a8fc-9becfef19917
# Printing out sketches from game: 7153-7156a665-f7f2-4d4c-a564-6860f102553c
# Printing out sketches from game: 8791-b1dcfcc0-9352-4400-8369-4d08ec32315f
# Printing out sketches from game: 1819-c3a24d90-67d5-4809-86e7-fd593aa8a5d4
# Printing out sketches from game: 5034-7b58800e-9ac1-4d02-92a8-2b254989f56a
# Printing out sketches from game: 7739-793fdb53-3984-416e-a150-18402825b54f
# Printing out sketches from game: 5907-3a9cd530-1185-49fb-b80c-a01b8135ab19
# Printing out sketches from game: 2464-c53624ef-35fd-4408-9c94-3cdd233debe7
# Printing out sketches from game: 7442-b6cc7ffe-65f4-4bd0-a58b-ee9f094dd790
# Printing out sketches from game: 0007-978f80e4-e27a-45b4-8084-7c0e90628426
# Printing out sketches from game: 1350-d657e06f-e679-4eb8-b73d-f2709da1f958
# Printing out sketches from game: 8242-be9b13ac-dcbb-409d-8273-385474deebcf
# Printing out sketches from game: 4754-285207b9-aa4d-4004-9c25-9b037e0cc76e
# Printing out sketches from game: 6610-9b5cd7f2-433c-42a9-a00b-7eb764377141
# Printing out sketches from game: 6675-0a3a8570-aeb6-4859-af81-a0a49490e336
# Printing out sketches from game: 5613-63f88b6b-4ce7-427e-8bf7-08d14ece0224
# Printing out sketches from game: 8920-5c5e45df-c4a7-4c73-b8b5-8bc5a7d639a0
# Printing out sketches from game: 1154-111c8889-c505-4bc8-ac56-ac5a2e8b225b

# %% [markdown]
# ### Print out sketches in separate folders

# %%
## print out sketches with target & distractors from this game in separate folders
import traceback
backup_path_images = '/Users/judithfan/Dropbox/stimuli_repository/subordinate_allrotations_6_minified'

_valid_gameids = valid_gameids[:3]

target_sketch_dir = os.path.join(analysis_dir,'sketches','sketch')
target_3D_dir = os.path.join(analysis_dir,'sketches','target')
distractor1_3D_dir = os.path.join(analysis_dir,'sketches','distractor1')
distractor2_3D_dir = os.path.join(analysis_dir,'sketches','distractor2')
distractor3_3D_dir = os.path.join(analysis_dir,'sketches','distractor3')
out_paths = [target_3D_dir,distractor1_3D_dir,distractor2_3D_dir,distractor3_3D_dir]


if not os.path.exists(target_3D_dir):
    os.makedirs(os.path.join(analysis_dir,'sketches','target'))
    os.makedirs(os.path.join(analysis_dir,'sketches','distractor1'))
    os.makedirs(os.path.join(analysis_dir,'sketches','distractor2'))
    os.makedirs(os.path.join(analysis_dir,'sketches','distractor3'))
    os.makedirs(os.path.join(analysis_dir,'sketches','sketch'))    

run_this = 1
if run_this:
    for g in valid_gameids:
        print 'Printing out sketches from game: ' + g
        _D = D[(D.gameID==g)]
        _D = _D.sort_values(by=['target'])
        _i = 1
        textsize=12
        fig = plt.figure(figsize=(16,6))        
        for i,_d in _D.iterrows():
            imgData = _d['png']
            filestr = base64.b64decode(imgData)
            if not os.path.exists(target_sketch_dir):
                os.makedirs(target_sketch_dir)
            fname = os.path.join(target_sketch_dir,'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '.png')
            with open(fname, "wb") as fh:
                fh.write(imgData.decode('base64'))
            im = Image.open(fname)
            im.save(fname)

            targetname = _d['target']
            distractors = [_d['Distractor1'],_d['Distractor2'],_d['Distractor3']]
            full_list = [_d['target'],_d['Distractor1'],_d['Distractor2'],_d['Distractor3']]         
            
            for (i,d) in enumerate(full_list):
                if os.path.exists(backup_path_images):
                    if hasattr(t, 'pose'):
                        fn = os.path.join(backup_path_images,get_actual_pose(d,pose)[0])
                    else:
                        fn = os.path.join(backup_path_images,get_actual_pose(d,35)[0])
                else:
                    if hasattr(t, 'pose'):
                        pose = _d['pose']
                        URL = build_url_from_filenames(get_actual_pose(d,pose)[0])
                    else:
                        URL = full_dict[d]
                    fn = cStringIO.StringIO(urllib.urlopen(URL).read())
                fig = plt.figure(figsize=(8,8))                    
                im = Image.open(fn)
                im = im.resize((256,256), Image.ANTIALIAS).convert('RGB')                                
                out_dirs = [target_3D_dir,distractor1_3D_dir,distractor2_3D_dir,distractor3_3D_dir]                
                out_path = os.path.join(out_dirs[i],'gameID_' + _d['gameID'] + '_trial_' + str(_d['trialNum']) + '.png')
                im.save(out_path)
# Out:
# Printing out sketches from game: 0535-a2298fee-9fee-480a-b610-97868839a2f3
# Printing out sketches from game: 6450-e912a14e-23df-4035-ac9a-b2cf74f15b98
# Printing out sketches from game: 7593-f0489503-8b0b-485a-ae39-e259368664ec
# Printing out sketches from game: 2204-3d282337-deb9-4e23-94b2-6cd048a8a033
# Printing out sketches from game: 2848-1779ba4d-c84b-4050-8a1f-e4b733ceb6a7
# Printing out sketches from game: 1445-76cc5a87-402d-4f8b-b58a-9e97a0613616
# Printing out sketches from game: 5874-f8051e0a-38ec-4cd4-97bd-e9293354ea19
# Printing out sketches from game: 8819-83e41234-d6c0-4b51-88e5-0f0dec886711
# Printing out sketches from game: 8303-b6a53fd7-758c-40fe-a2fc-c2ee44cd976e
# Printing out sketches from game: 9272-e3357074-a213-422e-9f2e-cd651eab81ab
# Printing out sketches from game: 8975-103e8e1a-5b9a-4a89-928c-4954f989b06b
# Printing out sketches from game: 3644-5c59877e-a907-4a31-b23b-5f4c9a0ef09a
# Printing out sketches from game: 3515-7815239c-7927-4d44-b3bf-11524bcc9bf6
# Printing out sketches from game: 8037-403f337e-748b-496c-a88f-db09ec862568
# Printing out sketches from game: 4677-e7bbc55f-fbf4-45d4-bf02-598e831e3427
# Printing out sketches from game: 7191-d5fd9020-902a-4f79-9843-a256c5dacb37
# Printing out sketches from game: 7948-e1fb7fa9-ffc4-468c-9c9f-fe8e1d4e3bc2
# Printing out sketches from game: 9327-c0beefca-0873-4b8a-9150-51c2a0fb82fc
# Printing out sketches from game: 1075-1cd285ee-23cc-431e-a957-40e72b57cd95
# Printing out sketches from game: 3687-f9f943c4-dd2d-4cc0-a28c-6033f019cfad
# Printing out sketches from game: 6119-217c3807-f595-4732-a2cc-66ae9b0f2a5f
# Printing out sketches from game: 3207-fde2baa0-61b8-45aa-b255-ebec98351506
# Printing out sketches from game: 0273-d557931d-9a9e-49e2-ac92-9da282521a06
# Printing out sketches from game: 4546-f9fcfb8d-a3be-42f3-9c65-3feda50858ff
# Printing out sketches from game: 0907-f76165c1-464e-426b-960d-02a18e0f468a
# Printing out sketches from game: 8727-a1a01879-fc3b-4837-b1fe-5729facc72df
# Printing out sketches from game: 7596-77f299a5-42bd-4985-83c2-eb7bf7d7bda9
# Printing out sketches from game: 7803-4b0bd7fd-829d-4de9-aa70-9be1cef8062f
# Printing out sketches from game: 7266-68826e7a-2875-4750-9ddc-4b5397aaf9a5
# Printing out sketches from game: 7848-f3fe2b6f-713b-4695-9fbd-ba4fa6897887
# Printing out sketches from game: 7522-6780f02a-dcc5-4663-99f0-9fb30ab8b1c8
# Printing out sketches from game: 2552-aa93cff3-83d0-4a21-91b6-0770489f09fc
# Printing out sketches from game: 4604-7927e887-3e5c-40b8-935c-536321ddf5d8
# Printing out sketches from game: 6773-64175755-f825-4336-85ad-9e0bfd230b69
# Printing out sketches from game: 4023-028179e7-5141-423e-aed3-750ebe1b7f0b
# Printing out sketches from game: 6106-603e561a-34d6-4660-ae8c-742d537c3c8d
# Printing out sketches from game: 4997-0bd6d143-637c-4248-b8e4-de5ece20c185
# Printing out sketches from game: 6224-ab96ed5c-2a98-477c-aae2-7398b9e5b237
# Printing out sketches from game: 6575-7d152f85-a68c-4282-872b-aa28797839b8
# Printing out sketches from game: 4178-df447b76-1be6-49c6-a42f-bd882d442998
# Printing out sketches from game: 5157-5c5cccb1-04ca-45cf-9c6d-3a9fe57c5ce2
# Printing out sketches from game: 5742-f8753fba-b31c-44f3-a3ad-76fa38df4345
# Printing out sketches from game: 7963-5ebb8094-114b-4727-93b4-c4719cacc33e
# Printing out sketches from game: 3968-35e2fcdb-c9e3-4556-9f7b-d47d38cbf130
# Printing out sketches from game: 4143-3aed2f05-e0e6-4117-9d93-1849a3a7e567
# Printing out sketches from game: 1960-02b34a68-8229-460a-9ee4-3b8a411cd76d
# Printing out sketches from game: 8651-485e82ff-2062-4121-9936-5089b41d6e95
# Printing out sketches from game: 0793-9115d164-4bed-4928-8031-630161232275
# Printing out sketches from game: 5360-6c999d75-4224-445c-b5c8-0b952d5c3afc
# Printing out sketches from game: 4905-7e1e70bf-3137-46b8-b321-f24646df3a02
# Printing out sketches from game: 8181-c44c672e-1f04-4d39-b984-dff5f557e8c9
# Printing out sketches from game: 3432-70b6af63-3c20-4dba-94fe-9f40a60b440d
# Printing out sketches from game: 1506-39dc44f7-ee0a-4610-bd1b-6b251cdc7286
# Printing out sketches from game: 9364-fa0394b1-f27b-4484-b04f-5f702f5295bf
# Printing out sketches from game: 8791-2219258a-dbbc-45ea-a65b-e0d4ab6f70ba
# Printing out sketches from game: 7601-00e2c292-0dd9-47d0-80c1-dedce5688994
# Printing out sketches from game: 9857-d7c518af-8951-43d2-b82c-b70083319e91
# Printing out sketches from game: 5613-9813bf94-70a7-4b1f-a211-ea5692bd70f3
# Printing out sketches from game: 6420-1b4bd32f-d5de-4d4b-83f9-f5c2b5378c46
# Printing out sketches from game: 6186-2f90eb49-9b9a-4809-9be6-29a90e024d4f
# Printing out sketches from game: 5396-864b6ad5-36a9-4e6f-ac73-2e7b848c394b
# Printing out sketches from game: 9460-e4d8a2fd-7a5a-4d25-ae41-127894d151ba
# Printing out sketches from game: 5062-3a0f07c2-94d8-46da-b07b-eec2b4a61ff4
# Printing out sketches from game: 7180-6ff89bfe-8682-412d-af98-c7deb0ad5a21
# Printing out sketches from game: 6247-a34e373a-217c-4a0a-a8fc-9becfef19917
# Printing out sketches from game: 7153-7156a665-f7f2-4d4c-a564-6860f102553c
# Printing out sketches from game: 8791-b1dcfcc0-9352-4400-8369-4d08ec32315f
# Printing out sketches from game: 1819-c3a24d90-67d5-4809-86e7-fd593aa8a5d4
# Printing out sketches from game: 5034-7b58800e-9ac1-4d02-92a8-2b254989f56a
# Printing out sketches from game: 7739-793fdb53-3984-416e-a150-18402825b54f
# Printing out sketches from game: 5907-3a9cd530-1185-49fb-b80c-a01b8135ab19
# Printing out sketches from game: 2464-c53624ef-35fd-4408-9c94-3cdd233debe7
# Printing out sketches from game: 7442-b6cc7ffe-65f4-4bd0-a58b-ee9f094dd790
# Printing out sketches from game: 0007-978f80e4-e27a-45b4-8084-7c0e90628426
# Printing out sketches from game: 1350-d657e06f-e679-4eb8-b73d-f2709da1f958
# Printing out sketches from game: 8242-be9b13ac-dcbb-409d-8273-385474deebcf
# Printing out sketches from game: 4754-285207b9-aa4d-4004-9c25-9b037e0cc76e
# Printing out sketches from game: 6610-9b5cd7f2-433c-42a9-a00b-7eb764377141
# Printing out sketches from game: 6675-0a3a8570-aeb6-4859-af81-a0a49490e336
# Printing out sketches from game: 5613-63f88b6b-4ce7-427e-8bf7-08d14ece0224
# Printing out sketches from game: 8920-5c5e45df-c4a7-4c73-b8b5-8bc5a7d639a0
# Printing out sketches from game: 1154-111c8889-c505-4bc8-ac56-ac5a2e8b225b
